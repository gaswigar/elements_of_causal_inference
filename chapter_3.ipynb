# %%
import numpy as np 
import seaborn as sns

# %% [markdown]
# # Problem 3.5

# %% [markdown]
# ![problem_35](images/problem_35.png)

# %%
NX = np.random.normal(loc =0, scale = 1, size= 200)
NY = np.random.normal(loc =0, scale = 1, size= 200)
Y = NY 
X = Y**(2) + NX
sns.histplot(x = X)
# Out:
# <AxesSubplot: ylabel='Count'>

# %% [markdown]
# # Problem 3.6

# %% [markdown]
# ![problem_36](images/problem_36.png)

# %% [markdown]
# # Problem 3.7

# %% [markdown]
# ![problem_37](images/problem_37.png)

# %% [markdown]
# # Problem 3.8

# %% [markdown]
# ![problem_38](images/problem_381.png)
# ![problem_38](images/problem_382.png)
